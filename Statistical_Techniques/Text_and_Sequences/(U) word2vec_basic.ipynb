# %% [markdown]
# <pre>
# ssh cspm-dev04
#
# export CONDA_ENVS_PATH=/mypath/conda_lib/
# module load anaconda3/4.3.0
# source activate loc
#
# export LD_LIBRARY_PATH=/usr/lib64/:/mypath/lib64/
# export KERAS_BACKEND=tensorflow
# export CUDA_VISIBLE_DEVICES=3
#
# jupyter-notebook --no-browser --ip=127.0.0.1
# </pre>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
fname = '/mypath/text.zip'

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

#filename = maybe_download('text8.zip', 31344016)
filename = maybe_download(fname, 31344016)

# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Found and verified /mypath/text.zip
# Data size 17005207

# %%
' '.join(words[0:50])
# Out:
# 'anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the'

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data[0:10]
# Out:
# [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
count[0:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
list(dictionary.keys())[0:10]
# Out:
# ['UNK', 'the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine']

# %%
dictionary['the']
# Out:
# 1

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
"anarchism originated as a term of abuse first"
# Out:
# 'anarchism originated as a term of abuse first'

# %%
# skip_window -> How many words to consider left and right.
# num_skips -> How many times to reuse an input to generate a label.
batch_size=16
num_skips=4
skip_window=2
batch, labels = generate_batch(batch_size=batch_size, num_skips=num_skips, skip_window=skip_window)
for i in range(batch_size):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 7 to -> 10713 pejorative
# 7 to -> 1325 describe
# 7 to -> 215 way
# 7 to -> 105 any
# 1325 describe -> 105 any
# 1325 describe -> 455 act
# 1325 describe -> 7 to
# 1325 describe -> 215 way
# 105 any -> 455 act
# 105 any -> 7 to
# 105 any -> 1325 describe
# 105 any -> 20 that
# 455 act -> 1325 describe
# 455 act -> 20 that
# 455 act -> 59 used
# 455 act -> 105 any

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/gpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 5000 == 0:
      if step > 0:
        average_loss /= 5000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 25000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  279.041564941
# Nearest to new: baku, bowled, dysrhythmias, lawlessness, dipping, fireballs, shortfalls, cheung,
# Nearest to its: elias, dealerships, sundance, italian, regulator, trafficking, stones, apologies,
# Nearest to all: tolstoy, monitoring, mike, ergot, escobar, unu, toolbars, based,
# Nearest to american: smashed, symmetry, inseparable, arms, thespis, waxes, combo, equating,
# Nearest to other: picture, reversals, soundboard, darkly, screename, reichenbach, bw, nord,
# Nearest to between: spectacularly, macworld, irrigated, menace, shrewd, pantomime, nullification, suffices,
# Nearest to for: interlude, blas, irvine, annalen, guanaco, pulling, dimona, coiled,
# Nearest to state: confusingly, filthy, sedentary, gray, maclennan, collapsed, civilized, kuril,
# Nearest to a: cairo, megabits, each, escorts, avoidance, eldest, imaginable, conakry,
# Nearest to four: cache, diesels, iturbide, chabad, rigidly, purchased, cryopreservation, cartoon,
# Nearest to as: cubist, ods, sportsmen, buffalo, tout, wheelchair, unmarried, arnauld,
# Nearest to more: advise, plantagenet, undermine, satisfies, gotta, congressman, host, frenetic,
# Nearest to have: transverse, demanded, craven, bamiyan, runs, chicago, eva, ashley,
# Nearest to been: morphology, mcpherson, kodansha, mastering, abandoning, bondage, abruptly, flaw,
# Nearest to can: denouncing, marysville, lasso, leftists, clowning, contractile, mccormack, sch,
# Nearest to i: recollections, mundi, image, detecting, notoriety, insurgency, allegations, labrador,
# Average loss at step  5000 :  74.1003311481
# Average loss at step  10000 :  22.2972028624
# Average loss at step  15000 :  12.1136449053
# Average loss at step  20000 :  8.85139436603
# Average loss at step  25000 :  7.05319208088
# Nearest to new: mazar, sloan, ride, fungi, victoriae, diet, patented, aaa,
# Nearest to its: the, their, his, this, davao, them, a, keying,
# Nearest to all: these, providers, mic, ministry, tolstoy, kirchenmusik, forearm, interstate,
# Nearest to american: smashed, symmetry, s, survived, expanded, jesse, origins, equity,
# Nearest to other: colombo, picture, mallow, bills, nord, restructuring, picks, eb,
# Nearest to between: jingles, hiddenstructure, eight, suspect, somers, and, chondrites, bills,
# Nearest to for: and, from, in, with, of, by, hiddenstructure, as,
# Nearest to state: gray, interstate, marathon, muscat, maple, accompanies, formation, collapsed,
# Nearest to a: the, this, fungi, keying, seen, meander, ministry, brane,
# Nearest to four: eight, seven, five, six, nine, two, zero, three,
# Nearest to as: and, mic, by, buffalo, bafta, is, in, for,
# Nearest to more: moxie, eb, ascending, sutton, advise, captains, side, cics,
# Nearest to have: be, had, transverse, demanded, are, fungi, were, interstate,
# Nearest to been: mcpherson, pngimage, morphology, to, olympus, abruptly, mic, was,
# Nearest to can: may, will, caves, could, bills, zero, magnate, tlatoani,
# Nearest to i: image, et, UNK, allegations, labrador, detecting, mundi, fungi,
# Average loss at step  30000 :  6.23644895787
# Average loss at step  35000 :  5.83191304727
# Average loss at step  40000 :  5.41004526467
# Average loss at step  45000 :  5.20898694901
# Average loss at step  50000 :  5.17385126877
# Nearest to new: agouti, sloan, bowled, one, aaa, fungi, patented, pacts,
# Nearest to its: their, the, his, them, agni, abet, this, keying,
# Nearest to all: these, many, ministry, mic, tolstoy, aorta, kirchenmusik, interstate,
# Nearest to american: english, smashed, german, french, british, symmetry, equity, thespis,
# Nearest to other: colombo, some, mallow, many, monoids, shinto, such, mic,
# Nearest to between: with, jingles, in, from, hiddenstructure, suspect, for, somers,
# Nearest to for: of, in, to, with, dasyprocta, hiddenstructure, when, and,
# Nearest to state: gray, interstate, maple, aleksandar, kuril, marathon, fungi, collapsed,
# Nearest to a: the, hbf, fungi, keying, this, or, brane, meander,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to as: buffalo, agouti, mic, became, kirchenmusik, bafta, apatosaurus, and,
# Nearest to more: most, moxie, less, plantagenet, advise, childish, sutton, victorious,
# Nearest to have: had, be, has, were, are, transverse, demanded, interstate,
# Nearest to been: was, be, mcpherson, by, pngimage, had, were, morphology,
# Nearest to can: may, could, will, would, should, must, might, to,
# Nearest to i: UNK, et, detecting, alum, image, absalom, honey, seventy,
# Average loss at step  55000 :  5.06446499243
# Average loss at step  60000 :  4.93672182512
# Average loss at step  65000 :  4.89012950764
# Average loss at step  70000 :  4.82252567077
# Average loss at step  75000 :  4.79599724245
# Nearest to new: agouti, sloan, gigantopithecus, mazar, recitative, aaa, northern, fungi,
# Nearest to its: their, his, the, them, abet, keying, mic, brane,
# Nearest to all: these, wct, many, any, both, kirchenmusik, some, mic,
# Nearest to american: english, german, british, french, smashed, equity, scottish, thespis,
# Nearest to other: many, some, colombo, mallow, monoids, such, these, three,
# Nearest to between: from, with, in, jingles, suspect, hiddenstructure, on, and,
# Nearest to for: hiddenstructure, booty, dasyprocta, ladd, seven, collective, kirchenmusik, with,
# Nearest to state: gray, imprints, appointees, eugenicist, aleksandar, fungi, interstate, maple,
# Nearest to a: the, keying, seen, meander, fungi, sociolinguistics, brane, mic,
# Nearest to four: five, six, three, eight, two, seven, nine, zero,
# Nearest to as: mic, became, bafta, agouti, buffalo, seven, agave, yoannis,
# Nearest to more: most, less, very, moxie, plantagenet, advise, childish, sprinkling,
# Nearest to have: had, has, were, be, are, interstate, transverse, tbs,
# Nearest to been: be, was, mcpherson, had, were, by, become, pngimage,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to i: they, et, detecting, alum, t, ii, honey, n,
# Average loss at step  80000 :  4.79064568086
# Average loss at step  85000 :  4.71418826542
# Average loss at step  90000 :  4.62983645058
# Average loss at step  95000 :  4.65938074942
# Average loss at step  100000 :  4.61506073635
# Nearest to new: agouti, shortfalls, michelob, gigantopithecus, recitative, mazar, mico, pulau,
# Nearest to its: their, the, his, them, her, abet, agni, keying,
# Nearest to all: these, many, any, some, both, wct, kirchenmusik, rested,
# Nearest to american: french, british, english, german, smashed, microcebus, canadian, scottish,
# Nearest to other: many, some, mallow, colombo, monoids, mico, various, these,
# Nearest to between: with, from, in, jingles, thaler, suspect, hiddenstructure, shorts,
# Nearest to for: of, busan, booty, or, ladd, winning, to, in,
# Nearest to state: michelob, aleksandar, cebus, kuril, gray, maple, appointees, eugenicist,
# Nearest to a: the, iit, sociolinguistics, thaler, every, seen, manchus, keying,
# Nearest to four: six, five, three, seven, eight, two, nine, zero,
# Nearest to as: mic, bafta, yoannis, microcebus, michelob, busan, agave, agouti,
# Nearest to more: less, most, very, childish, mitral, sprinkling, moxie, plantagenet,
# Nearest to have: had, has, were, are, be, interstate, transverse, destroy,
# Nearest to been: be, was, become, were, had, never, mcpherson, pngimage,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Nearest to i: et, ii, t, n, they, microcebus, g, detecting,

# %%
# %matplotlib inline

# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  #plt.savefig(filename)
  plt.show()

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=10000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
